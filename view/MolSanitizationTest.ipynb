# %%
import os
from configs.config import data_aug_dir
from rdkit import Chem
lig_84 = os.path.join(data_aug_dir["ligands"], "966c", "84_ledock001.mol2")
m = Chem.MolFromMol2File(lig_84, sanitize=False)
m

# %%
n = Chem.MolFromMol2File(lig_84, sanitize=True)
n

# %%
pro = os.path.join(data_aug_dir["proteins"], "966c.pdb")
pro
# Out:
# 'E:\\datasets\\data_aug\\docking_set_pro_pdb\\966c.pdb'

# %%
from util.ECIF import ECIF
ecif_helper = ECIF()
m_ecif_list = ecif_helper.get_ecif_mol2(pro, lig_84)
m_ld_list = ecif_helper.get_ligand_features_by_file_mol2(lig_84)

# %%
n_ecif_list = ecif_helper.get_ecif_mol2(pro, lig_84)
n_ld_list = ecif_helper.get_ligand_features_by_file_mol2(lig_84)

# %%
m_ecif_list == n_ecif_list
# Out:
# True

# %%
m_ld_list == n_ld_list
# Out:
# True
